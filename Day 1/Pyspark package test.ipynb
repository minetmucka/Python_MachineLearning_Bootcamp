# %%
spark

# %%
# %%info
# Out:
# Current session configs: <tt>{'conf': {'spark.pyspark.python': 'python3.6', 'spark.pyspark.virtualenv.enabled': 'true', 'spark.pyspark.virtualenv.type': 'native', 'spark.pyspark.virtualenv.bin.path': '/usr/bin/virtualenv'}, 'proxyUser': 'leelak', 'kind': 'pyspark3'}</tt><br>
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>Current session?</th></tr><tr><td>0</td><td>application_1582262204698_0001</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-10-131-132-131.tfs.toyota.com:20888/proxy/application_1582262204698_0001/">Link</a></td><td><a target="_blank" href="http://awva-pclap03036.tfs.toyota.com:8042/node/containerlogs/container_1582262204698_0001_01_000001/leelak">Link</a></td><td></td></tr><tr><td>1</td><td>application_1582262204698_0002</td><td>spark</td><td>idle</td><td><a target="_blank" href="http://ip-10-131-132-131.tfs.toyota.com:20888/proxy/application_1582262204698_0002/">Link</a></td><td><a target="_blank" href="http://awva-pclap03036.tfs.toyota.com:8042/node/containerlogs/container_1582262204698_0002_01_000001/leelak">Link</a></td><td></td></tr><tr><td>3</td><td>application_1582262204698_0004</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-10-131-132-131.tfs.toyota.com:20888/proxy/application_1582262204698_0004/">Link</a></td><td><a target="_blank" href="http://awva-pclap03037.tfs.toyota.com:8042/node/containerlogs/container_1582262204698_0004_01_000001/leelak">Link</a></td><td>✔</td></tr></table>

# %%
# %%configure -f
# { "conf":{
#           "spark.pyspark.python": "python3.6",
#           "spark.pyspark.virtualenv.enabled": "true",
#           "spark.pyspark.virtualenv.type":"native",
#           "spark.pyspark.virtualenv.bin.path":"/usr/bin/virtualenv"
#          }
# }
# Out:
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>Current session?</th></tr><tr><td>4</td><td>application_1582262204698_0005</td><td>pyspark3</td><td>idle</td><td><a target="_blank" href="http://ip-10-131-132-131.tfs.toyota.com:20888/proxy/application_1582262204698_0005/">Link</a></td><td><a target="_blank" href="http://awva-pclap03037.tfs.toyota.com:8042/node/containerlogs/container_1582262204698_0005_01_000001/leelak">Link</a></td><td>✔</td></tr></table>
# SparkSession available as 'spark'.
# Current session configs: <tt>{'conf': {'spark.pyspark.python': 'python3.6', 'spark.pyspark.virtualenv.enabled': 'true', 'spark.pyspark.virtualenv.type': 'native', 'spark.pyspark.virtualenv.bin.path': '/usr/bin/virtualenv'}, 'proxyUser': 'leelak', 'kind': 'pyspark3'}</tt><br>
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>Current session?</th></tr><tr><td>0</td><td>application_1582262204698_0001</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-10-131-132-131.tfs.toyota.com:20888/proxy/application_1582262204698_0001/">Link</a></td><td><a target="_blank" href="http://awva-pclap03036.tfs.toyota.com:8042/node/containerlogs/container_1582262204698_0001_01_000001/leelak">Link</a></td><td></td></tr><tr><td>1</td><td>application_1582262204698_0002</td><td>spark</td><td>idle</td><td><a target="_blank" href="http://ip-10-131-132-131.tfs.toyota.com:20888/proxy/application_1582262204698_0002/">Link</a></td><td><a target="_blank" href="http://awva-pclap03036.tfs.toyota.com:8042/node/containerlogs/container_1582262204698_0002_01_000001/leelak">Link</a></td><td></td></tr><tr><td>4</td><td>application_1582262204698_0005</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-10-131-132-131.tfs.toyota.com:20888/proxy/application_1582262204698_0005/">Link</a></td><td><a target="_blank" href="http://awva-pclap03037.tfs.toyota.com:8042/node/containerlogs/container_1582262204698_0005_01_000001/leelak">Link</a></td><td>✔</td></tr></table>

# %%
sc.list_packages()
# Out:
# Package                    Version
# -------------------------- --------------
# absl-py                    0.9.0
# alembic                    1.4.0
# astor                      0.8.1
# attrs                      19.3.0
# Automat                    20.2.0
# backcall                   0.1.0
# beautifulsoup4             4.7.1
# BigDL                      0.10.0
# bleach                     3.1.1
# blis                       0.4.1
# blurhash                   1.1.4
# bokeh                      1.4.0
# boost                      0.1
# boto                       2.49.0
# boto3                      1.12.3
# botocore                   1.15.3
# cachetools                 4.0.0
# catalogue                  1.0.0
# catboost                   0.21
# Cerberus                   1.3.2
# certifi                    2019.11.28
# cffi                       1.14.0
# chardet                    3.0.4
# Click                      7.0
# click-plugins              1.1.1
# cligj                      0.5.0
# cloudpickle                1.3.0
# colorama                   0.4.3
# configparser               4.0.2
# confluent-kafka            1.3.0
# constantly                 15.1.0
# crypto                     1.4.1
# cryptography               2.8
# cssselect                  1.1.0
# cycler                     0.10.0
# cymem                      2.0.3
# Cython                     0.29.15
# databricks-cli             0.9.1
# decorator                  4.4.1
# defusedxml                 0.6.0
# dist-keras                 0.2.1
# docker                     4.2.0
# docutils                   0.15.2
# elephas                    0.4.3
# eli5                       0.10.1
# entrypoints                0.3
# factor-analyzer            0.3.1
# Fiona                      1.8.13
# Flask                      1.1.1
# future                     0.18.2
# gast                       0.3.3
# gensim                     3.8.1
# geopandas                  0.7.0
# gitdb2                     3.0.2
# GitPython                  3.0.8
# glog                       0.3.1
# google-auth                1.11.2
# google-auth-oauthlib       0.4.1
# google-pasta               0.1.8
# gorilla                    0.3.0
# graphviz                   0.11
# grpcio                     1.27.2
# gunicorn                   20.0.4
# h2o                        3.28.0.3
# h2o-pysparkling-2.4        3.28.0.3.post1
# h5py                       2.10.0
# hyperas                    0.4.1
# hyperlink                  19.0.0
# hyperopt                   0.2.3
# idna                       2.9
# imageio                    2.8.0
# importlib-metadata         1.5.0
# incremental                17.5.0
# ipaddress                  1.0.23
# ipykernel                  5.1.4
# ipython                    7.12.0
# ipython-genutils           0.2.0
# ipywidgets                 7.5.1
# itsdangerous               1.1.0
# jedi                       0.16.0
# Jinja2                     2.11.1
# jmespath                   0.9.4
# joblib                     0.14.1
# jsonschema                 3.2.0
# jupyter                    1.0.0
# jupyter-client             5.3.4
# jupyter-console            6.1.0
# jupyter-core               4.6.3
# Keras                      2.3.1
# Keras-Applications         1.0.8
# Keras-Preprocessing        1.1.0
# kiwisolver                 1.1.0
# lightgbm                   2.3.1
# lxml                       4.3.4
# Mako                       1.1.1
# Markdown                   3.2.1
# MarkupSafe                 1.1.1
# Mastodon.py                1.5.0
# matplotlib                 3.1.3
# mistune                    0.8.4
# mlflow                     1.6.0
# munch                      2.5.0
# murmurhash                 1.0.2
# mxnet                      1.4.0
# mysqlclient                1.4.2.post1
# Naked                      0.1.31
# nbconvert                  5.6.1
# nbformat                   5.0.4
# networkx                   2.4
# nltk                       3.4.3
# nose                       1.3.4
# notebook                   6.0.3
# numpy                      1.14.5
# oauthlib                   3.1.0
# opencv-python              4.2.0.32
# packaging                  20.1
# pandas                     1.0.1
# pandocfilters              1.4.2
# parsel                     1.5.2
# parso                      0.6.1
# patsy                      0.5.1
# pexpect                    4.8.0
# pickleshare                0.7.5
# Pillow                     7.0.0
# pip                        20.0.2
# plac                       1.1.3
# plotly                     4.5.1
# polyglot                   16.7.4
# postgres                   3.0.0
# preshed                    3.0.2
# presto-python-client       0.7.0
# prometheus-client          0.7.1
# prometheus-flask-exporter  0.12.2
# prompt-toolkit             3.0.3
# Protego                    0.1.16
# protobuf                   3.11.3
# psycopg2-binary            2.8.4
# psycopg2-pool              1.1
# ptyprocess                 0.6.0
# py-dateutil                2.2
# py4j                       0.10.7
# pyaml                      19.12.0
# pyasn1                     0.4.8
# pyasn1-modules             0.2.8
# pycparser                  2.19
# pycrypto                   2.6.1
# PyDispatcher               2.0.5
# pydot                      1.4.1
# Pygments                   2.5.2
# PyHamcrest                 2.0.0
# pyOpenSSL                  19.1.0
# pypandoc                   1.4
# pyparsing                  2.4.6
# pyproj                     2.4.2.post1
# pyrsistent                 0.15.7
# pyspark                    2.4.5
# python-dateutil            2.8.1
# python-editor              1.0.4
# python-gflags              3.1.2
# python-json-logger         0.1.11
# python-magic               0.4.15
# python36-sagemaker-pyspark 1.2.4
# pytz                       2019.1
# PyWavelets                 1.1.1
# PyYAML                     3.11
# pyzmq                      18.1.1
# qtconsole                  4.6.0
# querystring-parser         1.2.4
# queuelib                   1.5.0
# regex                      2020.2.20
# requests                   2.23.0
# requests-oauthlib          1.3.0
# retrying                   1.3.3
# rsa                        4.0
# s3transfer                 0.3.3
# scikit-image               0.16.2
# scikit-learn               0.22.1
# scikit-optimize            0.7.2
# scipy                      1.4.1
# Scrapy                     1.8.0
# seaborn                    0.10.0
# Send2Trash                 1.5.0
# service-identity           18.1.0
# setuptools                 45.2.0
# Shapely                    1.7.0
# shellescape                3.8.1
# simplejson                 3.17.0
# six                        1.12.0
# smart-open                 1.9.0
# smmap2                     2.0.5
# soupsieve                  1.9.1
# spacy                      2.2.3
# SQLAlchemy                 1.3.13
# sqlparse                   0.3.0
# srsly                      1.0.1
# statsmodels                0.11.0
# tabulate                   0.8.6
# tensorboard                2.1.0
# tensorflow                 1.14.0
# tensorflow-estimator       1.14.0
# tensorflowonspark          1.4.4
# termcolor                  1.1.0
# terminado                  0.8.3
# testpath                   0.4.4
# textblob                   0.15.3
# Theano                     1.0.4
# thinc                      7.3.1
# tornado                    6.0.3
# tqdm                       4.43.0
# traitlets                  4.3.3
# Twisted                    19.10.0
# tzlocal                    2.0.0
# urllib3                    1.25.8
# varclushi                  0.1.0
# w3lib                      1.21.0
# wasabi                     0.6.0
# wcwidth                    0.1.8
# webencodings               0.5.1
# websocket-client           0.57.0
# Werkzeug                   1.0.0
# wheel                      0.34.2
# widgetsnbextension         3.5.1
# windmill                   1.6
# wrapt                      1.12.0
# xgboost                    1.0.0
# xlrd                       1.2.0
# XlsxWriter                 1.2.7
# xlwt                       1.3.0
# XML2Dict                   0.2.2
# zipp                       3.0.0
# zope.interface             4.7.1
#
# WARNING: The directory '/home/.cache/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.

# %%
import sys, os, imp, site
print('\n'.join(sys.path))
os.path.join("/opt/conda/pkgs/")
sys.path.append("/opt/conda/lib/python3.6/site-packages/")
print('\n'.join(sys.path))
site.getusersitepackages()
# Out:
# /mnt/yarn/usercache/leelak/appcache/application_1576880024092_0434/container_1576880024092_0434_01_000001/tmp
# /mnt/yarn/usercache/leelak/appcache/application_1576880024092_0434/spark-21058ac6-252c-4546-ae19-d4858cc555c3/userFiles-145d540c-fa91-4787-a119-1ed4145cfad3
# /mnt/yarn/usercache/leelak/appcache/application_1576880024092_0434/container_1576880024092_0434_01_000001/pyspark.zip
# /mnt/yarn/usercache/leelak/appcache/application_1576880024092_0434/container_1576880024092_0434_01_000001/py4j-0.10.7-src.zip
# /usr/lib64/python3.6
# /usr/lib64/python3.6/lib-dynload
# /usr/local/lib64/python3.6/site-packages
# /usr/local/lib/python3.6/site-packages
# /usr/lib64/python3.6/dist-packages
# /usr/lib/python3.6/dist-packages
# /opt/conda/lib/python3.6/site-packages/
# /mnt/yarn/usercache/leelak/appcache/application_1576880024092_0434/container_1576880024092_0434_01_000001/tmp
# /mnt/yarn/usercache/leelak/appcache/application_1576880024092_0434/spark-21058ac6-252c-4546-ae19-d4858cc555c3/userFiles-145d540c-fa91-4787-a119-1ed4145cfad3
# /mnt/yarn/usercache/leelak/appcache/application_1576880024092_0434/container_1576880024092_0434_01_000001/pyspark.zip
# /mnt/yarn/usercache/leelak/appcache/application_1576880024092_0434/container_1576880024092_0434_01_000001/py4j-0.10.7-src.zip
# /usr/lib64/python3.6
# /usr/lib64/python3.6/lib-dynload
# /usr/local/lib64/python3.6/site-packages
# /usr/local/lib/python3.6/site-packages
# /usr/lib64/python3.6/dist-packages
# /usr/lib/python3.6/dist-packages
# /opt/conda/lib/python3.6/site-packages/
# /opt/conda/lib/python3.6/site-packages/
# '/home/.local/lib/python3.6/site-packages'

# %%
import seaborn

# %%
from cryptography.fernet import Fernet

# %%
# %%local
# ! pip show cryptography
# ! ls /opt/conda/bin/python3.6
# Out:
# Name: cryptography
# Version: 2.6.1
# Summary: cryptography is a package which provides cryptographic recipes and primitives to Python developers.
# Home-page: https://github.com/pyca/cryptography
# Author: The cryptography developers
# Author-email: cryptography-dev@python.org
# License: BSD or Apache License, Version 2.0
# Location: /opt/conda/lib/python3.6/site-packages
# Requires: cffi, six, asn1crypto
# You are using pip version 9.0.3, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# ls: cannot access '/opt/conda/bin/python3.6/': Not a directory

# %%
spark.list_packages()
# Out:
# 'SparkSession' object has no attribute 'list_packages'
# Traceback (most recent call last):
# AttributeError: 'SparkSession' object has no attribute 'list_packages'
